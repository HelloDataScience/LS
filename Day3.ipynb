# %%
import os
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\USER\\Documents\\project\\code'

# %%
os.chdir('../data')

# %%
os.listdir()
# Out:
# ['APT_Detail_Seoul_2023.csv',
#  'APT_Detail_Seoul_2023.xlsx',
#  'APT_List.pkl',
#  'APT_Price_Seoul(2020~2023).xlsx',
#  'APT_Price_Seoul_2020.csv',
#  'APT_Price_Seoul_2021.csv',
#  'APT_Price_Seoul_2022.csv',
#  'APT_Price_Seoul_2023.csv',
#  'NA_Sample.xlsx']

# %%
prc = pd.read_pickle('APT_List.pkl')

# %%
prc.head()
# Out:
#     지역코드         아파트    시도명  시군구  법정동    지번    건축년도         거래일    전용면적   층  \
# 0  11680  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-04   49.86   6
# 1  11680    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019.0  2020-01-04   94.29  12
# 2  11680        개포자이  서울특별시  강남구  개포동  12-2  2004.0  2020-01-06  134.30  17
# 3  11680      개포우성3차  서울특별시  강남구  개포동   652  1984.0  2020-01-09  133.46   3
# 4  11680  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-10   39.53   2
#
#       거래금액
# 0  124,500
# 1  285,000
# 2  203,000
# 3  220,000
# 4  103,000

# %%
prc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175754 entries, 0 to 175753
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   지역코드    175754 non-null  int64
#  1   아파트     175754 non-null  object
#  2   시도명     175754 non-null  object
#  3   시군구     175754 non-null  object
#  4   법정동     175754 non-null  object
#  5   지번      175732 non-null  object
#  6   건축년도    175749 non-null  float64
#  7   거래일     175754 non-null  object
#  8   전용면적    175754 non-null  float64
#  9   층       175754 non-null  int64
#  10  거래금액    175754 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 14.7+ MB

# %%
prc['지역코드']
# Out:
# 0         11680
# 1         11680
# 2         11680
# 3         11680
# 4         11680
#           ...
# 175749    11260
# 175750    11260
# 175751    11260
# 175752    11260
# 175753    11260
# Name: 지역코드, Length: 175754, dtype: int64

# %%
prc.loc[:, '지역코드']
# Out:
# 0         11680
# 1         11680
# 2         11680
# 3         11680
# 4         11680
#           ...
# 175749    11260
# 175750    11260
# 175751    11260
# 175752    11260
# 175753    11260
# Name: 지역코드, Length: 175754, dtype: int64

# %%
prc[['거래일', '전용면적', '층', '거래금액']]
# Out:
#                거래일    전용면적   층     거래금액
# 0       2020-01-04   49.86   6  124,500
# 1       2020-01-04   94.29  12  285,000
# 2       2020-01-06  134.30  17  203,000
# 3       2020-01-09  133.46   3  220,000
# 4       2020-01-10   39.53   2  103,000
# ...            ...     ...  ..      ...
# 175749  2023-12-02   59.76   7   60,000
# 175750  2023-12-03   71.83   2   47,500
# 175751  2023-12-07   84.69   8   73,000
# 175752  2023-12-09   59.76  11   60,000
# 175753  2023-12-21   84.87   6   74,350
#
# [175754 rows x 4 columns]

# %%
prc.loc[:, ['거래일', '전용면적', '층', '거래금액']]
# Out:
#                거래일    전용면적   층     거래금액
# 0       2020-01-04   49.86   6  124,500
# 1       2020-01-04   94.29  12  285,000
# 2       2020-01-06  134.30  17  203,000
# 3       2020-01-09  133.46   3  220,000
# 4       2020-01-10   39.53   2  103,000
# ...            ...     ...  ..      ...
# 175749  2023-12-02   59.76   7   60,000
# 175750  2023-12-03   71.83   2   47,500
# 175751  2023-12-07   84.69   8   73,000
# 175752  2023-12-09   59.76  11   60,000
# 175753  2023-12-21   84.87   6   74,350
#
# [175754 rows x 4 columns]

# %%
# prc['거래일':'거래금액']
prc.loc[:, '거래일':'거래금액']
# Out:
#                거래일    전용면적   층     거래금액
# 0       2020-01-04   49.86   6  124,500
# 1       2020-01-04   94.29  12  285,000
# 2       2020-01-06  134.30  17  203,000
# 3       2020-01-09  133.46   3  220,000
# 4       2020-01-10   39.53   2  103,000
# ...            ...     ...  ..      ...
# 175749  2023-12-02   59.76   7   60,000
# 175750  2023-12-03   71.83   2   47,500
# 175751  2023-12-07   84.69   8   73,000
# 175752  2023-12-09   59.76  11   60,000
# 175753  2023-12-21   84.87   6   74,350
#
# [175754 rows x 4 columns]

# %%
prc.dtypes
# Out:
# 지역코드      int64
# 아파트      object
# 시도명      object
# 시군구      object
# 법정동      object
# 지번       object
# 건축년도    float64
# 거래일      object
# 전용면적    float64
# 층         int64
# 거래금액     object
# dtype: object

# %%
cond = (prc.dtypes == 'int64')
prc.loc[:, cond]
# Out:
#          지역코드   층
# 0       11680   6
# 1       11680  12
# 2       11680  17
# 3       11680   3
# 4       11680   2
# ...       ...  ..
# 175749  11260   7
# 175750  11260   2
# 175751  11260   8
# 175752  11260  11
# 175753  11260   6
#
# [175754 rows x 2 columns]

# %%
cond = (prc.dtypes == 'int64') | (prc.dtypes == 'float64')
prc.loc[:, cond]
# Out:
#          지역코드    건축년도    전용면적   층
# 0       11680  1992.0   49.86   6
# 1       11680  2019.0   94.29  12
# 2       11680  2004.0  134.30  17
# 3       11680  1984.0  133.46   3
# 4       11680  1992.0   39.53   2
# ...       ...     ...     ...  ..
# 175749  11260  1998.0   59.76   7
# 175750  11260  2003.0   71.83   2
# 175751  11260  1997.0   84.69   8
# 175752  11260  1997.0   59.76  11
# 175753  11260  1997.0   84.87   6
#
# [175754 rows x 4 columns]

# %%
prc.select_dtypes(include = [int, float])
# Out:
#          지역코드    건축년도    전용면적   층
# 0       11680  1992.0   49.86   6
# 1       11680  2019.0   94.29  12
# 2       11680  2004.0  134.30  17
# 3       11680  1984.0  133.46   3
# 4       11680  1992.0   39.53   2
# ...       ...     ...     ...  ..
# 175749  11260  1998.0   59.76   7
# 175750  11260  2003.0   71.83   2
# 175751  11260  1997.0   84.69   8
# 175752  11260  1997.0   59.76  11
# 175753  11260  1997.0   84.87   6
#
# [175754 rows x 4 columns]

# %%
prc = prc.drop(columns = ['지역코드'])

# %%
prc.head()
# Out:
#           아파트    시도명  시군구  법정동    지번    건축년도         거래일    전용면적   층     거래금액
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-04   49.86   6  124,500
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019.0  2020-01-04   94.29  12  285,000
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004.0  2020-01-06  134.30  17  203,000
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984.0  2020-01-09  133.46   3  220,000
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-10   39.53   2  103,000

# %%
prc.rename(columns = {'시도명': '시', '시군구': '구', '법정동': '동'})
# Out:
#                    아파트      시    구    동      지번    건축년도         거래일    전용면적  \
# 0           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-04   49.86
# 1             디에이치아너힐즈  서울특별시  강남구  개포동     138  2019.0  2020-01-04   94.29
# 2                 개포자이  서울특별시  강남구  개포동    12-2  2004.0  2020-01-06  134.30
# 3               개포우성3차  서울특별시  강남구  개포동     652  1984.0  2020-01-09  133.46
# 4           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-10   39.53
# ...                ...    ...  ...  ...     ...     ...         ...     ...
# 175749  한신아파트(101~102)  서울특별시  중랑구  중화동     450  1998.0  2023-12-02   59.76
# 175750         한영(101)  서울특별시  중랑구  중화동  274-51  2003.0  2023-12-03   71.83
# 175751  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-07   84.69
# 175752  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-09   59.76
# 175753  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-21   84.87
#
#          층     거래금액
# 0        6  124,500
# ...

# %%
prc.columns
# Out:
# Index(['아파트', '시도명', '시군구', '법정동', '지번', '건축년도', '거래일', '전용면적', '층', '거래금액'], dtype='object')

# %%
prc.columns = ['아파트', '시', '구', '동', '지번', '건축년도', 
               '거래일', '전용면적', '층', '거래금액']

# %%
prc.head()
# Out:
#           아파트      시    구    동    지번    건축년도         거래일    전용면적   층     거래금액
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-04   49.86   6  124,500
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019.0  2020-01-04   94.29  12  285,000
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004.0  2020-01-06  134.30  17  203,000
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984.0  2020-01-09  133.46   3  220,000
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-10   39.53   2  103,000

# %%
prc['거래금액'] = prc['거래금액'].str.replace(pat = ',', repl = '') \
                                 .astype('int64')

# %%
prc['거래금액'].astype(str).str.replace(pat = ',', repl = '')
# Out:
# 0         124500
# 1         285000
# 2         203000
# 3         220000
# 4         103000
#            ...
# 175749     60000
# 175750     47500
# 175751     73000
# 175752     60000
# 175753     74350
# Name: 거래금액, Length: 175754, dtype: object

# %%
prc.dtypes
# Out:
# 아파트      object
# 시        object
# 구        object
# 동        object
# 지번       object
# 건축년도    float64
# 거래일      object
# 전용면적    float64
# 층         int64
# 거래금액      int64
# dtype: object

# %%
prc['거래일'] = prc['거래일'].astype('datetime64[ns]')

# %%
prc.dtypes
# Out:
# 아파트             object
# 시               object
# 구               object
# 동               object
# 지번              object
# 건축년도           float64
# 거래일     datetime64[ns]
# 전용면적           float64
# 층                int64
# 거래금액             int64
# dtype: object

# %%
cond = (prc['거래금액'] >= 1200000)
df1 = prc.loc[cond, :]
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층  \
# 123113      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2
# 128446      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 135998  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
# 138784      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 172266      파르크한남  서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670   4
#
#            거래금액
# 123113  1200000
# 128446  1450000
# 135998  1300000
# 138784  1350000
# 172266  1800000

# %%
cond = (prc['거래금액'] < 1200000) & (prc['층'] >= 65)
df2 = prc.loc[cond, :]
df2
# Out:
#             아파트      시    구    동      지번    건축년도        거래일     전용면적   층  \
# 1326     타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2020-07-25  235.740  67
# 1429     타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2020-10-27  185.622  66
# 68048   현대하이페리온  서울특별시  양천구   목동     916  2003.0 2020-07-03  154.050  66
# 85043    타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2021-06-24  214.967  66
# 141488   타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2023-12-22  185.622  68
# 168579  현대하이페리온  서울특별시  양천구   목동     916  2003.0 2023-07-03  167.440  65
#
#           거래금액
# 1326    542500
# 1429    380000
# 68048   240000
# 85043   458000
# 141488  550000
# 168579  320000

# %%
cond = prc['구'].eq('강남구')
prc.loc[cond, :].shape[0]
# Out:
# 9157

# %%
cond = prc['구'].eq('강남구') & prc['동'].eq('압구정동')
prc.loc[cond, :].shape[0]
# Out:
# 745

# %%
cond1 = prc['구'].eq('강남구')
cond2 = prc['구'].eq('서초구')
cond3 = prc['구'].eq('송파구')
prc.loc[cond1 | cond2 | cond3, :].shape[0]
# Out:
# 27153

# %% [raw]
# prc.loc[prc['구'].eq('강남구') | prc['구'].eq('서초구') | prc['구'].eq('송파구'), :].shape[0]

# %%
cond = prc['구'].isin(values = ['강남구', '서초구', '송파구'])
prc.loc[cond, :].shape[0]
# Out:
# 27153

# %%
cond = prc['구'].isin(values = ['강남', '서초', '송파'])
prc.loc[cond, :].shape[0]
# Out:
# 0

# %%
cond = prc['구'].str.contains(pat = '(강남|서초|송파)구')
prc.loc[cond, :].shape[0]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10668\3897725502.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   cond = prc['구'].str.contains(pat = '(강남|서초|송파)구')
# 27153

# %%
cond = prc['구'].isin(values = ['강남구', '강동구', '강서구', '강북구'])
prc.loc[cond, :].shape[0]
# Out:
# 33578

# %%
cond = prc['구'].str.contains(pat = '강[남동서북]구')
cond = prc['구'].str.contains(pat = '^강')
prc.loc[cond, :].shape[0]
# Out:
# 33578

# %%
addr = pd.Series(data = ['서울특별시 강남구', '서울시 서초구', '경기도 성남시 분당구'])

# %%
addr.str.slice(0, 2)
# Out:
# 0    서울
# 1    서울
# 2    경기
# dtype: object

# %%
addr.str.extract(pat = '([가-힣 ]+시)')
# Out:
#          0
# 0    서울특별시
# 1      서울시
# 2  경기도 성남시

# %%
addr.str.replace(pat = '([가-힣 ]+시)', repl = '', regex = True)
# Out:
# 0     강남구
# 1     서초구
# 2     분당구
# dtype: object

# %%
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층  \
# 123113      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2
# 128446      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 135998  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
# 138784      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 172266      파르크한남  서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670   4
#
#            거래금액
# 123113  1200000
# 128446  1450000
# 135998  1300000
# 138784  1350000
# 172266  1800000

# %%
df1.drop(index = [123113, 128446])
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층  \
# 135998  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
# 138784      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 172266      파르크한남  서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670   4
#
#            거래금액
# 135998  1300000
# 138784  1350000
# 172266  1800000

# %%
df1.index
# Out:
# Index([123113, 128446, 135998, 138784, 172266], dtype='int64')

# %%
df1.drop(index = df1.index[0:2])
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층  \
# 135998  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
# 138784      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 172266      파르크한남  서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670   4
#
#            거래금액
# 135998  1300000
# 138784  1350000
# 172266  1800000

# %%
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층  \
# 123113      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2
# 128446      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 135998  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
# 138784      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 172266      파르크한남  서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670   4
#
#            거래금액
# 123113  1200000
# 128446  1450000
# 135998  1300000
# 138784  1350000
# 172266  1800000

# %%
df1.reset_index()
# Out:
#     index        아파트      시    구      동       지번    건축년도        거래일     전용면적  \
# 0  123113      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950
# 1  128446      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960
# 2  135998  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546
# 3  138784      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670
# 4  172266      파르크한남  서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670
#
#     층     거래금액
# 0   2  1200000
# 1  16  1450000
# 2  47  1300000
# 3   5  1350000
# 4   4  1800000

# %%
df1.reset_index().drop(columns = 'index')
# Out:
#          아파트      시    구      동       지번    건축년도        거래일     전용면적   층  \
# 0      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2
# 1      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 2  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
# 3      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 4      파르크한남  서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670   4
#
#       거래금액
# 0  1200000
# 1  1450000
# 2  1300000
# 3  1350000
# 4  1800000

# %%
df1.reset_index(drop = True)
# Out:
#          아파트      시    구      동       지번    건축년도        거래일     전용면적   층  \
# 0      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2
# 1      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 2  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
# 3      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 4      파르크한남  서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670   4
#
#       거래금액
# 0  1200000
# 1  1450000
# 2  1300000
# 3  1350000
# 4  1800000

# %%
df1.set_index(keys = '아파트').reset_index()
# Out:
#                시    구      동       지번    건축년도        거래일     전용면적   층     거래금액
# 아파트
# 파르크한남      서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  1200000
# PH129      서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16  1450000
# 아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47  1300000
# 파르크한남      서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5  1350000
# 파르크한남      서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670   4  1800000

# %%
prc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175754 entries, 0 to 175753
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   아파트     175754 non-null  object
#  1   시       175754 non-null  object
#  2   구       175754 non-null  object
#  3   동       175754 non-null  object
#  4   지번      175732 non-null  object
#  5   건축년도    175749 non-null  float64
#  6   거래일     175754 non-null  datetime64[ns]
#  7   전용면적    175754 non-null  float64
#  8   층       175754 non-null  int64
#  9   거래금액    175754 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 13.4+ MB

# %%
prc.isna()
# Out:
#           아파트      시      구      동     지번   건축년도    거래일   전용면적      층   거래금액
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 175749  False  False  False  False  False  False  False  False  False  False
# 175750  False  False  False  False  False  False  False  False  False  False
# 175751  False  False  False  False  False  False  False  False  False  False
# 175752  False  False  False  False  False  False  False  False  False  False
# 175753  False  False  False  False  False  False  False  False  False  False
#
# [175754 rows x 10 columns]

# %%
prc.isna().sum()
# Out:
# 아파트      0
# 시        0
# 구        0
# 동        0
# 지번      22
# 건축년도     5
# 거래일      0
# 전용면적     0
# 층        0
# 거래금액     0
# dtype: int64

# %%
prc.isnull().sum()
# Out:
# 아파트      0
# 시        0
# 구        0
# 동        0
# 지번      22
# 건축년도     5
# 거래일      0
# 전용면적     0
# 층        0
# 거래금액     0
# dtype: int64

# %%
prc.notna().sum()
# Out:
# 아파트     175754
# 시       175754
# 구       175754
# 동       175754
# 지번      175732
# 건축년도    175749
# 거래일     175754
# 전용면적    175754
# 층       175754
# 거래금액    175754
# dtype: int64

# %%
cond = prc['지번'].isna()
prc.loc[cond, :]
# Out:
#                   아파트      시    구    동   지번    건축년도        거래일    전용면적  층  \
# 54410   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-01-20   84.99  3
# 54411   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-01-23   84.95  1
# 54415   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-02-22  114.90  1
# 54442   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-07-09   84.95  4
# 54445   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-07-18   84.95  8
# 54448   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-07-27  101.90  3
# 54453   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-08-26  114.90  5
# 54455   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-08-29  114.90  9
# 54461   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-10-06   84.95  1
# 54465   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-11-18   84.95  9
# 54468   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-12-03   84.95  6
# 111834  힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2021-03-11   84.95  2
# ...

# %%
cond = prc['아파트'].eq('힐스테이트 서초 젠트리스')
prc.loc[cond, '지번'] = '557'

# %%
prc.isna().sum()
# Out:
# 아파트     0
# 시       0
# 구       0
# 동       0
# 지번      0
# 건축년도    5
# 거래일     0
# 전용면적    0
# 층       0
# 거래금액    0
# dtype: int64

# %%
cond = prc['건축년도'].isna()
prc.loc[cond, :]
# Out:
#               아파트      시    구    동   지번  건축년도        거래일     전용면적   층    거래금액
# 139053  DMCSKVIEW  서울특별시  은평구  수색동  418   NaN 2022-01-26  84.9900   6  137000
# 139057  DMCSKVIEW  서울특별시  은평구  수색동  418   NaN 2022-02-10  84.9900   6  137000
# 173090  DMCSKVIEW  서울특별시  은평구  수색동  418   NaN 2023-09-23  59.9865  23  110000
# 173099  DMCSKVIEW  서울특별시  은평구  수색동  418   NaN 2023-10-18  84.9926  17  117000
# 173111  DMCSKVIEW  서울특별시  은평구  수색동  418   NaN 2023-12-22  59.9865   6   99700

# %%
prc.loc[cond, :].fillna(value = 9999)
# Out:
#               아파트      시    구    동   지번    건축년도        거래일     전용면적   층  \
# 139053  DMCSKVIEW  서울특별시  은평구  수색동  418  9999.0 2022-01-26  84.9900   6
# 139057  DMCSKVIEW  서울특별시  은평구  수색동  418  9999.0 2022-02-10  84.9900   6
# 173090  DMCSKVIEW  서울특별시  은평구  수색동  418  9999.0 2023-09-23  59.9865  23
# 173099  DMCSKVIEW  서울특별시  은평구  수색동  418  9999.0 2023-10-18  84.9926  17
# 173111  DMCSKVIEW  서울특별시  은평구  수색동  418  9999.0 2023-12-22  59.9865   6
#
#           거래금액
# 139053  137000
# 139057  137000
# 173090  110000
# 173099  117000
# 173111   99700

# %%
prc.loc[cond, '건축년도'].fillna(value = 9999)
# Out:
# 139053    9999.0
# 139057    9999.0
# 173090    9999.0
# 173099    9999.0
# 173111    9999.0
# Name: 건축년도, dtype: float64

# %%
prc['건축년도'].mean()
# Out:
# 2001.7659047846646

# %%
prc.loc[cond, '건축년도'].fillna(value = prc['건축년도'].mean())
# Out:
# 139053    2001.765905
# 139057    2001.765905
# 173090    2001.765905
# 173099    2001.765905
# 173111    2001.765905
# Name: 건축년도, dtype: float64

# %%
prc['건축년도'] = prc['건축년도'].fillna(value = 9999)

# %%
prc.isna().sum()
# Out:
# 아파트     0
# 시       0
# 구       0
# 동       0
# 지번      0
# 건축년도    0
# 거래일     0
# 전용면적    0
# 층       0
# 거래금액    0
# dtype: int64

# %%
os.listdir()
# Out:
# ['APT_Detail_Seoul_2023.csv',
#  'APT_Detail_Seoul_2023.xlsx',
#  'APT_List.pkl',
#  'APT_Price_Seoul(2020~2023).xlsx',
#  'APT_Price_Seoul_2020.csv',
#  'APT_Price_Seoul_2021.csv',
#  'APT_Price_Seoul_2022.csv',
#  'APT_Price_Seoul_2023.csv',
#  'NA_Sample.xlsx']

# %%
na = pd.read_excel('NA_Sample.xlsx')

# %%
na
# Out:
#     구분 항목    값
# 0    A  a  1.2
# 1  NaN  b  2.3
# 2  NaN  c  3.5
# 3    B  a  1.7
# 4  NaN  b  2.6
# 5  NaN  c  3.6

# %%
na.ffill()
# Out:
#   구분 항목    값
# 0  A  a  1.2
# 1  A  b  2.3
# 2  A  c  3.5
# 3  B  a  1.7
# 4  B  b  2.6
# 5  B  c  3.6

# %%
cond = prc['건축년도'].eq(9999)
prc.loc[cond, '건축년도'] = np.NaN

# %%
prc.isna().sum()
# Out:
# 아파트     0
# 시       0
# 구       0
# 동       0
# 지번      0
# 건축년도    5
# 거래일     0
# 전용면적    0
# 층       0
# 거래금액    0
# dtype: int64

# %%
prc.shape
# Out:
# (175754, 10)

# %%
prc.dropna().shape
# Out:
# (175749, 10)

# %%
prc.dropna(axis = 1).shape
# Out:
# (175754, 9)

# %%
prc.dropna(subset = '건축년도')
# Out:
# (175749, 10)

# %%
prc = prc.dropna(subset = '건축년도')

# %%
prc.shape
# Out:
# (175749, 10)

# %%
prc['건축년도'] = prc['건축년도'].astype('int64')

# %%
prc.dtypes
# Out:
# 아파트             object
# 시               object
# 구               object
# 동               object
# 지번              object
# 건축년도             int64
# 거래일     datetime64[ns]
# 전용면적           float64
# 층                int64
# 거래금액             int64
# dtype: object

# %%
prc['평당금액'] = prc['거래금액'] / prc['전용면적'] * 3.3

# %%
prc['거래금액'] = prc['거래금액'] / 10000

# %%
prc.head()
# Out:
#           아파트      시    구    동    지번  건축년도        거래일    전용면적   층   거래금액  \
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-04   49.86   6  12.45
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019 2020-01-04   94.29  12  28.50
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004 2020-01-06  134.30  17  20.30
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984 2020-01-09  133.46   3  22.00
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-10   39.53   2  10.30
#
#           평당금액
# 0  8240.072202
# 1  9974.546612
# 2  4988.086374
# 3  5439.832159
# 4  8598.532760

# %%
def squared(x):
    y = x ** 2
    return y

# %%
squared(x = 2)
# Out:
# 4

# %%
(lambda x: x ** 2)(2)
# Out:
# 4

# %%
squared2 = lambda x: x ** 2

# %%
squared2(x = 2)
# Out:
# 4

# %%
# 문자열 포맷팅: 변수가 가리키는 값을 문자열에 대입하는 것!
name = '손흥민'
name + ' 고객님 안녕하세요?'
# Out:
# '손흥민 고객님 안녕하세요?'

# %%
'%s 고객님 안녕하세요?' %(name)
# Out:
# '손흥민 고객님 안녕하세요?'

# %%
'{0} 고객님 안녕하세요?'.format(name)
# Out:
# '손흥민 고객님 안녕하세요?'

# %%
# f string 포맷팅
f'{name} 고객님 안녕하세요?'
# Out:
# '손흥민 고객님 안녕하세요?'

# %%
rate = 0.234567

# %%
'고객님의 이자율은 %.3f %%입니다.' %(rate)
# Out:
# '고객님의 이자율은 0.235 %입니다.'

# %%
'고객님의 이자율은 {0:.3f} %입니다.'.format(rate)
# Out:
# '고객님의 이자율은 0.235 %입니다.'

# %%
f'고객님의 이자율은 {rate:.3f} %입니다.'
# Out:
# '고객님의 이자율은 0.235 %입니다.'

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')

# %%
prc.head()
# Out:
#           아파트      시    구    동    지번  건축년도        거래일   전용면적   층  거래금액    평당금액
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-04  49.86   6 12.45 8240.07
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019 2020-01-04  94.29  12 28.50 9974.55
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004 2020-01-06 134.30  17 20.30 4988.09
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984 2020-01-09 133.46   3 22.00 5439.83
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-10  39.53   2 10.30 8598.53

# %%
prc['거래년도'] = prc['거래일'].dt.year

# %%
prc['경과년수'] = prc['거래년도'] - prc['건축년도']

# %%
prc['거래월'] = prc['거래일'].dt.strftime(date_format = '%m월')

# %%
prc.head()
# Out:
#           아파트      시    구    동    지번  건축년도        거래일   전용면적   층  거래금액  \
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-04  49.86   6 12.45
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019 2020-01-04  94.29  12 28.50
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004 2020-01-06 134.30  17 20.30
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984 2020-01-09 133.46   3 22.00
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-10  39.53   2 10.30
#
#      평당금액  거래년도  경과년수  거래월
# 0 8240.07  2020    28  01월
# 1 9974.55  2020     1  01월
# 2 4988.09  2020    16  01월
# 3 5439.83  2020    36  01월
# 4 8598.53  2020    28  01월

# %%
prc['거래월'] = prc['거래월'].str.replace(pat = '^0', repl = '', regex = True)

# %%
prc.head()
# Out:
#           아파트      시    구    동    지번  건축년도        거래일   전용면적   층  거래금액  \
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-04  49.86   6 12.45
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019 2020-01-04  94.29  12 28.50
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004 2020-01-06 134.30  17 20.30
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984 2020-01-09 133.46   3 22.00
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-10  39.53   2 10.30
#
#      평당금액  거래년도  경과년수 거래월
# 0 8240.07  2020    28  1월
# 1 9974.55  2020     1  1월
# 2 4988.09  2020    16  1월
# 3 5439.83  2020    36  1월
# 4 8598.53  2020    28  1월

# %%
result = []
for i in prc['평당금액']:
    if i >= 5000:
        result.append('5천 이상')
    else:
        result.append('5천 미만')
print(result)
# Out:
# ['5천 이상', '5천 이상', '5천 미만', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 미만', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 미만', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 미만', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상', '5천 이상'
# ...

# %%
prc['금액구간'] = np.NaN
for i in range(len(prc['평당금액'])):
    if prc['평당금액'].iloc[i] >= 5000:
        prc['금액구간'].iloc[i] = '5천 이상'
    else:
        prc['금액구간'].iloc[i] = '5천 미만'
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10668\328782321.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   prc['금액구간'].iloc[i] = '5천 이상'
# ...

# %%
prc.head()
# Out:
#           아파트      시    구    동    지번  건축년도        거래일   전용면적   층  거래금액  \
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-04  49.86   6 12.45
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019 2020-01-04  94.29  12 28.50
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004 2020-01-06 134.30  17 20.30
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984 2020-01-09 133.46   3 22.00
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-10  39.53   2 10.30
#
#      평당금액  거래년도  경과년수 거래월   금액구간
# 0 8240.07  2020    28  1월  5천 이상
# 1 9974.55  2020     1  1월  5천 이상
# 2 4988.09  2020    16  1월  5천 미만
# 3 5439.83  2020    36  1월  5천 이상
# 4 8598.53  2020    28  1월  5천 이상

# %%
cond = prc['평당금액'].ge(5000)
prc['금액구간'] = np.where(cond, '5천 이상', '5천 미만')

# %%
prc['아파트']
# Out:
# 0             성원대치2단지아파트
# 1               디에이치아너힐즈
# 2                   개포자이
# 3                 개포우성3차
# 4             성원대치2단지아파트
#                ...
# 175749    한신아파트(101~102)
# 175750           한영(101)
# 175751    한신아파트(103~109)
# 175752    한신아파트(103~109)
# 175753    한신아파트(103~109)
# Name: 아파트, Length: 175749, dtype: object

# %%
prc['아파트'].map(len)
# Out:
# 0         10
# 1          8
# 2          4
# 3          6
# 4         10
#           ..
# 175749    14
# 175750     7
# 175751    14
# 175752    14
# 175753    14
# Name: 아파트, Length: 175749, dtype: int64

# %%
cond = prc['아파트'].map(len).ge(10)
prc.loc[cond, :]
# Out:
#                      아파트      시    구    동     지번  건축년도        거래일  전용면적   층  \
# 0             성원대치2단지아파트  서울특별시  강남구  개포동     12  1992 2020-01-04 49.86   6
# 4             성원대치2단지아파트  서울특별시  강남구  개포동     12  1992 2020-01-10 39.53   2
# 7             성원대치2단지아파트  서울특별시  강남구  개포동     12  1992 2020-01-13 39.53  14
# 10            성원대치2단지아파트  서울특별시  강남구  개포동     12  1992 2020-01-28 39.53   3
# 19      우성9차아파트901동,902동  서울특별시  강남구  개포동  651-1  1991 2020-02-12 84.90   9
# ...                  ...    ...  ...  ...    ...   ...        ...   ...  ..
# 175747    한신아파트(103~109)  서울특별시  중랑구  중화동    450  1997 2023-11-19 59.76   6
# 175749    한신아파트(101~102)  서울특별시  중랑구  중화동    450  1998 2023-12-02 59.76   7
# 175751    한신아파트(103~109)  서울특별시  중랑구  중화동    450  1997 2023-12-07 84.69   8
# 175752    한신아파트(103~109)  서울특별시  중랑구  중화동    450  1997 2023-12-09 59.76  11
# 175753    한신아파트(103~109)  서울특별시  중랑구  중화동    450  1997 2023-12-21 84.87   6
#
#         거래금액    평당금액  거래년도  경과년수  거래월   금액구간
# ...

# %%
cols = ['시', '구', '동', '지번']
prc[cols]
# Out:
#             시    구    동      지번
# 0       서울특별시  강남구  개포동      12
# 1       서울특별시  강남구  개포동     138
# 2       서울특별시  강남구  개포동    12-2
# 3       서울특별시  강남구  개포동     652
# 4       서울특별시  강남구  개포동      12
# ...       ...  ...  ...     ...
# 175749  서울특별시  중랑구  중화동     450
# 175750  서울특별시  중랑구  중화동  274-51
# 175751  서울특별시  중랑구  중화동     450
# 175752  서울특별시  중랑구  중화동     450
# 175753  서울특별시  중랑구  중화동     450
#
# [175749 rows x 4 columns]

# %%
prc[cols].apply(len)
# Out:
# 시     175749
# 구     175749
# 동     175749
# 지번    175749
# dtype: int64

# %%
prc[cols].apply(len, axis = 1)
# Out:
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
#          ..
# 175749    4
# 175750    4
# 175751    4
# 175752    4
# 175753    4
# Length: 175749, dtype: int64

# %%
prc[cols].map(len)
# Out:
#         시  구  동  지번
# 0       5  3  3   2
# 1       5  3  3   3
# 2       5  3  3   4
# 3       5  3  3   3
# 4       5  3  3   2
# ...    .. .. ..  ..
# 175749  5  3  3   3
# 175750  5  3  3   6
# 175751  5  3  3   3
# 175752  5  3  3   3
# 175753  5  3  3   3
#
# [175749 rows x 4 columns]

# %%
'서울특별시' + ' ' + '강남구' + ' ' + '역삼동' + ' ' + '1'
# Out:
# '서울특별시 강남구 역삼동 1'

# %%
prc['시'] + ' ' + prc['구'] + ' ' + prc['동'] + ' ' + prc['지번']
# Out:
# 0             서울특별시 강남구 개포동 12
# 1            서울특별시 강남구 개포동 138
# 2           서울특별시 강남구 개포동 12-2
# 3            서울특별시 강남구 개포동 652
# 4             서울특별시 강남구 개포동 12
#                   ...
# 175749       서울특별시 중랑구 중화동 450
# 175750    서울특별시 중랑구 중화동 274-51
# 175751       서울특별시 중랑구 중화동 450
# 175752       서울특별시 중랑구 중화동 450
# 175753       서울특별시 중랑구 중화동 450
# Length: 175749, dtype: object

# %%
addr = ['서울특별시', '강남구', '역삼동', '1']

# %%
' '.join(addr)
# Out:
# '서울특별시 강남구 역삼동 1'

# %%
prc[cols]
# Out:
#             시    구    동      지번
# 0       서울특별시  강남구  개포동      12
# 1       서울특별시  강남구  개포동     138
# 2       서울특별시  강남구  개포동    12-2
# 3       서울특별시  강남구  개포동     652
# 4       서울특별시  강남구  개포동      12
# ...       ...  ...  ...     ...
# 175749  서울특별시  중랑구  중화동     450
# 175750  서울특별시  중랑구  중화동  274-51
# 175751  서울특별시  중랑구  중화동     450
# 175752  서울특별시  중랑구  중화동     450
# 175753  서울특별시  중랑구  중화동     450
#
# [175749 rows x 4 columns]

# %%
prc['주소'] = prc[cols].apply(func = lambda x: ' '.join(x), axis = 1)

# %%
prc.head()
# Out:
#           아파트      시    구    동    지번  건축년도        거래일   전용면적   층  거래금액  \
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-04  49.86   6 12.45
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019 2020-01-04  94.29  12 28.50
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004 2020-01-06 134.30  17 20.30
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984 2020-01-09 133.46   3 22.00
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-10  39.53   2 10.30
#
#      평당금액  거래년도  경과년수 거래월   금액구간                  주소
# 0 8240.07  2020    28  1월  5천 이상    서울특별시 강남구 개포동 12
# 1 9974.55  2020     1  1월  5천 이상   서울특별시 강남구 개포동 138
# 2 4988.09  2020    16  1월  5천 미만  서울특별시 강남구 개포동 12-2
# 3 5439.83  2020    36  1월  5천 이상   서울특별시 강남구 개포동 652
# 4 8598.53  2020    28  1월  5천 이상    서울특별시 강남구 개포동 12

# %%
import seaborn as sns

# %%
iris = sns.load_dataset(name = 'iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0          5.10         3.50          1.40         0.20  setosa
# 1          4.90         3.00          1.40         0.20  setosa
# 2          4.70         3.20          1.30         0.20  setosa
# 3          4.60         3.10          1.50         0.20  setosa
# 4          5.00         3.60          1.40         0.20  setosa

# %% [raw]
# !pip install scipy

# %%
from scipy import stats

# %%
stats.pearsonr(x = iris['sepal_length'], y = iris['petal_width'])[0]
# Out:
# 0.8179411262715756

# %%
iris = iris.select_dtypes(include = [float])
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0          5.10         3.50          1.40         0.20
# 1          4.90         3.00          1.40         0.20
# 2          4.70         3.20          1.30         0.20
# 3          4.60         3.10          1.50         0.20
# 4          5.00         3.60          1.40         0.20

# %%
iris.apply(func = lambda x: stats.pearsonr(x = x, y = iris['petal_width'])[0])
# Out:
# sepal_length    0.82
# sepal_width    -0.37
# petal_length    0.96
# petal_width     1.00
# dtype: float64

# %%
# %whos -v DataFrame
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df1        DataFrame                  아파트      시 <...>0000  \n172266  1800000
# df2        DataFrame                아파트      시   <...>-07-03 167.44  65  320000
# iris       DataFrame         sepal_length  sepal_<...>n\n[150 rows x 4 columns]
# na         DataFrame        구분 항목    값\n0    A  a<...>N  b 2.60\n5  NaN  c 3.60
# prc        DataFrame                       아파트   <...>175749 rows x 16 columns]

# %%
prc.head()
# Out:
#           아파트      시    구    동    지번  건축년도        거래일   전용면적   층  거래금액  \
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-04  49.86   6 12.45
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019 2020-01-04  94.29  12 28.50
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004 2020-01-06 134.30  17 20.30
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984 2020-01-09 133.46   3 22.00
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992 2020-01-10  39.53   2 10.30
#
#      평당금액  거래년도  경과년수 거래월   금액구간                  주소
# 0 8240.07  2020    28  1월  5천 이상    서울특별시 강남구 개포동 12
# 1 9974.55  2020     1  1월  5천 이상   서울특별시 강남구 개포동 138
# 2 4988.09  2020    16  1월  5천 미만  서울특별시 강남구 개포동 12-2
# 3 5439.83  2020    36  1월  5천 이상   서울특별시 강남구 개포동 652
# 4 8598.53  2020    28  1월  5천 이상    서울특별시 강남구 개포동 12

# %%
prc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175749 entries, 0 to 175753
# Data columns (total 16 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   아파트     175749 non-null  object
#  1   시       175749 non-null  object
#  2   구       175749 non-null  object
#  3   동       175749 non-null  object
#  4   지번      175749 non-null  object
#  5   건축년도    175749 non-null  int64
#  6   거래일     175749 non-null  datetime64[ns]
#  7   전용면적    175749 non-null  float64
#  8   층       175749 non-null  int64
#  9   거래금액    175749 non-null  float64
#  10  평당금액    175749 non-null  float64
#  11  거래년도    175749 non-null  int32
#  12  경과년수    175749 non-null  int64
#  13  거래월     175749 non-null  object
#  14  금액구간    175749 non-null  object
#  15  주소      175749 non-null  object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(3), object(8)
# memory usage: 22.1+ MB

# %%
prc.isna().sum()
# Out:
# 아파트     0
# 시       0
# 구       0
# 동       0
# 지번      0
# 건축년도    0
# 거래일     0
# 전용면적    0
# 층       0
# 거래금액    0
# 평당금액    0
# 거래년도    0
# 경과년수    0
# 거래월     0
# 금액구간    0
# 주소      0
# dtype: int64

# %%
prc['층'].sort_values()
# Out:
# 173860    -3
# 79174     -3
# 78829     -3
# 57134     -2
# 58916     -2
#           ..
# 1429      66
# 85043     66
# 68048     66
# 1326      67
# 141488    68
# Name: 층, Length: 175749, dtype: int64

# %%
prc['층'].sort_values(ascending = False)
# Out:
# 141488    68
# 1326      67
# 85043     66
# 68048     66
# 1429      66
#           ..
# 57085     -2
# 79041     -2
# 78829     -3
# 173860    -3
# 79174     -3
# Name: 층, Length: 175749, dtype: int64

# %%
prc.sort_values(by = '층')
# Out:
#                               아파트      시    구    동      지번  건축년도        거래일  \
# 173860  우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2023-07-29
# 79174   우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2020-07-23
# 78829   우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2020-03-20
# 57134             옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-07-30
# 58916                    롯데캐슬골든힐스  서울특별시  성북구  길음동  1287-1  2019 2020-06-27
# ...                           ...    ...  ...  ...     ...   ...        ...
# 1429                       타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27
# 85043                      타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24
# 68048                     현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03
# 1326                       타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25
# 141488                     타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2023-12-22
#
# ...

# %%
prc.sort_values(by = '층', ascending = False)
# Out:
#                               아파트      시    구    동      지번  건축년도        거래일  \
# 141488                     타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2023-12-22
# 1326                       타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25
# 85043                      타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24
# 68048                     현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03
# 1429                       타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27
# ...                           ...    ...  ...  ...     ...   ...        ...
# 57085             옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-06-30
# 79041   우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2020-07-01
# 78829   우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2020-03-20
# 173860  우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2023-07-29
# 79174   우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2020-07-23
#
# ...

# %%
prc.sort_values(by = ['층', '거래금액'], ascending = False)
# Out:
#                               아파트      시    구    동      지번  건축년도        거래일  \
# 141488                     타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2023-12-22
# 1326                       타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25
# 85043                      타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24
# 1429                       타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27
# 68048                     현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03
# ...                           ...    ...  ...  ...     ...   ...        ...
# 58916                    롯데캐슬골든힐스  서울특별시  성북구  길음동  1287-1  2019 2020-06-27
# 24920                   천왕연지타운2단지  서울특별시  구로구  천왕동     281  2014 2020-07-02
# 173860  우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2023-07-29
# 79174   우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2020-07-23
# 78829   우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2020-03-20
#
# ...

# %%
prc.sort_values(by = ['층', '거래금액'], ascending = [False, True])
# Out:
#                               아파트      시    구    동      지번  건축년도        거래일  \
# 141488                     타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2023-12-22
# 1326                       타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25
# 68048                     현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03
# 1429                       타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27
# 85043                      타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24
# ...                           ...    ...  ...  ...     ...   ...        ...
# 57134             옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-07-30
# 162885            옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2023-05-25
# 78829   우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2020-03-20
# 79174   우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2020-07-23
# 173860  우물골2단지두산위브(223~244동)BL2-7  서울특별시  은평구  진관동      84  2010 2023-07-29
#
# ...

# %%
prc['거래금액'].count()
# Out:
# 175749

# %%
prc['거래금액'].sum()
# Out:
# 1659609.581

# %%
prc['거래금액'].mean()
# Out:
# 9.44306699326881

# %%
prc['거래금액'].median()
# Out:
# 7.79

# %%
prc['거래금액'].std()
# Out:
# 6.999414319367676

# %%
prc['거래금액'].var()
# Out:
# 48.99180081416927

# %%
prc['거래금액'].min()
# Out:
# 0.6

# %%
prc['거래금액'].max()
# Out:
# 180.0

# %%
prc.groupby(by = '거래년도')['거래금액'].count()
# Out:
# 거래년도
# 2020    84140
# 2021    43465
# 2022    12735
# 2023    35409
# Name: 거래금액, dtype: int64

# %%
prc.groupby(by = '거래년도')['거래금액'].sum()
# Out:
# 거래년도
# 2020   712842.97
# 2021   446458.81
# 2022   123999.94
# 2023   376307.86
# Name: 거래금액, dtype: float64

# %%
prc.groupby(by = '거래년도')['거래금액'].mean()
# Out:
# 거래년도
# 2020    8.47
# 2021   10.27
# 2022    9.74
# 2023   10.63
# Name: 거래금액, dtype: float64

# %%
prc.groupby(by = '거래년도')['거래금액'].std()
# Out:
# 거래년도
# 2020   5.68
# 2021   7.51
# 2022   9.47
# 2023   7.77
# Name: 거래금액, dtype: float64

# %%
prc.groupby(by = '거래년도')['거래금액'].min()
# Out:
# 거래년도
# 2020   0.60
# 2021   0.66
# 2022   0.67
# 2023   0.74
# Name: 거래금액, dtype: float64

# %%
prc.groupby(by = '거래년도')['거래금액'].max()
# Out:
# 거래년도
# 2020    77.50
# 2021   120.00
# 2022   145.00
# 2023   180.00
# Name: 거래금액, dtype: float64

# %%
prc['거래금액'].agg(func = ['mean', 'std'])
# Out:
# mean   9.44
# std    7.00
# Name: 거래금액, dtype: float64

# %%
prc.groupby(by = '거래년도')['거래금액'].agg(func = ['mean', 'std'])
# Out:
#       mean  std
# 거래년도
# 2020  8.47 5.68
# 2021 10.27 7.51
# 2022  9.74 9.47
# 2023 10.63 7.77

# %%
prc.groupby(by = '구')['거래금액'] \
   .agg(func = ['mean', 'std']) \
   .sort_values(by = 'mean', ascending = False)

# %%
prc.groupby(by = ['구', '거래년도'])['거래금액'] \
   .agg(func = ['mean', 'std']) \
   .to_excel('pivot_table.xlsx')

# %%
pd.pivot_table(data = prc, 
               values = '거래금액', 
               index = ['구', '동'], 
               columns = '거래년도', 
               aggfunc = 'mean', 
               margins = True, 
               margins_name = '합계')
# Out:
# 거래년도     2020  2021  2022  2023    합계
# 구   동
# 강남구 개포동 17.81 21.09 21.31 18.70 19.05
#     논현동 11.50 12.43 12.27 13.41 12.20
#     대치동 22.37 23.63 22.52 26.53 24.05
#     도곡동 21.06 25.03 27.26 24.96 23.63
#     삼성동 15.87 19.33 25.05 23.56 19.22
# ...       ...   ...   ...   ...   ...
# 중랑구 묵동   5.91  7.13  5.27  5.49  6.11
#     상봉동  5.37  7.20  4.38  5.81  5.59
#     신내동  4.89  6.27  6.12  5.51  5.45
#     중화동  5.01  6.35  4.27  5.20  5.38
# 합계       8.47 10.27  9.74 10.63  9.44
#
# [335 rows x 5 columns]

# %%
prc['구'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
prc['구'].nunique()
# Out:
# 25

# %%
prc['구'].value_counts()
# Out:
# 구
# 노원구     16590
# 강서구     11161
# 송파구     10225
# 구로구      9982
# 성북구      9176
# 강남구      9157
# 강동구      9020
# 도봉구      8013
# 영등포구     7818
# 서초구      7771
# 양천구      7412
# 은평구      7372
# 동대문구     7044
# 성동구      6495
# 마포구      6361
# 동작구      6295
# 중랑구      6056
# 서대문구     5870
# 관악구      5645
# 강북구      4240
# 금천구      3657
# 용산구      3253
# 광진구      3013
# 중구       2389
# 종로구      1734
# Name: count, dtype: int64

# %%
prc['구'].value_counts().sort_index()
# Out:
# 구
# 강남구      9157
# 강동구      9020
# 강북구      4240
# 강서구     11161
# 관악구      5645
# 광진구      3013
# 구로구      9982
# 금천구      3657
# 노원구     16590
# 도봉구      8013
# 동대문구     7044
# 동작구      6295
# 마포구      6361
# 서대문구     5870
# 서초구      7771
# 성동구      6495
# 성북구      9176
# 송파구     10225
# 양천구      7412
# 영등포구     7818
# 용산구      3253
# 은평구      7372
# 종로구      1734
# 중구       2389
# 중랑구      6056
# Name: count, dtype: int64

# %%
prc['구'].value_counts(normalize = True) * 100
# Out:
# 구
# 노원구    9.44
# 강서구    6.35
# 송파구    5.82
# 구로구    5.68
# 성북구    5.22
# 강남구    5.21
# 강동구    5.13
# 도봉구    4.56
# 영등포구   4.45
# 서초구    4.42
# 양천구    4.22
# 은평구    4.19
# 동대문구   4.01
# 성동구    3.70
# 마포구    3.62
# 동작구    3.58
# 중랑구    3.45
# 서대문구   3.34
# 관악구    3.21
# 강북구    2.41
# 금천구    2.08
# 용산구    1.85
# 광진구    1.71
# 중구     1.36
# 종로구    0.99
# Name: proportion, dtype: float64

# %%
cols = ['구', '거래년도']
prc[cols]
# Out:
#           구  거래년도
# 0       강남구  2020
# 1       강남구  2020
# 2       강남구  2020
# 3       강남구  2020
# 4       강남구  2020
# ...     ...   ...
# 175749  중랑구  2023
# 175750  중랑구  2023
# 175751  중랑구  2023
# 175752  중랑구  2023
# 175753  중랑구  2023
#
# [175749 rows x 2 columns]

# %%
prc[cols].value_counts().sort_index().reset_index()
# Out:
#       구  거래년도  count
# 0   강남구  2020   3718
# 1   강남구  2021   2254
# 2   강남구  2022    873
# 3   강남구  2023   2312
# 4   강동구  2020   4236
# ..  ...   ...    ...
# 95   중구  2023    538
# 96  중랑구  2020   2902
# 97  중랑구  2021   1651
# 98  중랑구  2022    553
# 99  중랑구  2023    950
#
# [100 rows x 3 columns]

# %%
pd.crosstab(index = [prc['구'], prc['동']], 
            columns = prc['거래년도'], 
            normalize = 'index', 
            margins = True, 
            margins_name = '합계')
# Out:
# 거래년도     2020  2021  2022  2023
# 구   동
# 강남구 개포동  0.38  0.23  0.06  0.34
#     논현동  0.37  0.34  0.15  0.14
#     대치동  0.34  0.22  0.10  0.33
#     도곡동  0.41  0.26  0.10  0.23
#     삼성동  0.44  0.27  0.11  0.19
# ...       ...   ...   ...   ...
# 중랑구 묵동   0.49  0.27  0.08  0.17
#     상봉동  0.43  0.21  0.23  0.14
#     신내동  0.51  0.30  0.05  0.14
#     중화동  0.48  0.29  0.06  0.17
# 합계       0.48  0.25  0.07  0.20
#
# [335 rows x 4 columns]

# %%
pd.crosstab(index = [prc['구'], prc['동']], 
            columns = prc['거래월'], 
            normalize = 'index', 
            margins = True, 
            margins_name = '합계') * 100
# Out:
# 거래월      10월  11월  12월    1월    2월   3월    4월    5월    6월    7월   8월   9월
# 구   동
# 강남구 개포동 5.46 5.37 7.28  8.58  9.01 6.59  6.59  9.97 13.26 11.18 9.79 6.93
#     논현동 7.48 8.11 7.48  6.86  7.90 7.28  7.69 10.81 12.27 10.19 8.11 5.82
#     대치동 5.13 5.39 6.81  4.86  8.31 6.19  9.99 12.56 20.42  8.49 7.34 4.51
#     도곡동 4.57 7.08 6.93  7.01  7.86 6.79  8.65 11.79 14.30  9.86 7.65 7.51
#     삼성동 7.06 9.08 5.48  6.48  8.07 5.62  5.76  7.93 22.33  6.77 8.65 6.77
# ...      ...  ...  ...   ...   ...  ...   ...   ...   ...   ...  ...  ...
# 중랑구 묵동  5.75 5.43 5.64  8.31  9.80 9.37 10.22  8.52 14.06  9.69 7.67 5.54
#     상봉동 4.72 6.29 5.31  8.06  8.16 5.80  7.28 24.19  8.46 10.91 6.39 4.42
#     신내동 5.66 3.98 5.61  8.91 10.93 8.41  6.61  7.68 18.33 10.26 7.34 6.28
#     중화동 6.17 4.11 6.68 10.28 12.60 9.77  6.94  7.46 11.57 11.31 7.97 5.14
# 합계      5.61 6.04 6.62  8.59  9.00 7.47  6.88  9.28 14.59 11.61 8.10 6.20
#
# [335 rows x 12 columns]

# %%
prc.describe()
# Out:
#            건축년도                            거래일      전용면적         층      거래금액  \
# count 175749.00                         175749 175749.00 175749.00 175749.00
# mean    2001.77  2021-06-19 01:18:19.793455616     74.44      9.25      9.44
# min     1961.00            2020-01-01 00:00:00     10.16     -3.00      0.60
# 25%     1995.00            2020-06-29 00:00:00     59.34      4.00      5.20
# 50%     2002.00            2021-01-21 00:00:00     74.50      8.00      7.79
# 75%     2009.00            2022-04-13 00:00:00     84.96     13.00     11.60
# max     2023.00            2023-12-31 00:00:00    317.36     68.00    180.00
# std       10.48                            NaN     31.50      6.25      7.00
#
#            평당금액      거래년도      경과년수
# count 175749.00 175749.00 175749.00
# mean    4134.01   2021.00     19.23
# min      471.35   2020.00     -1.00
# 25%     2721.81   2020.00     12.00
# 50%     3615.47   2021.00     19.00
# 75%     4958.26   2022.00     26.00
# ...

# %%
prc.describe(include = [int, float])
# Out:
#            건축년도      전용면적         층      거래금액      평당금액      거래년도      경과년수
# count 175749.00 175749.00 175749.00 175749.00 175749.00 175749.00 175749.00
# mean    2001.77     74.44      9.25      9.44   4134.01   2021.00     19.23
# std       10.48     31.50      6.25      7.00   2084.95      1.16     10.40
# min     1961.00     10.16     -3.00      0.60    471.35   2020.00     -1.00
# 25%     1995.00     59.34      4.00      5.20   2721.81   2020.00     12.00
# 50%     2002.00     74.50      8.00      7.79   3615.47   2021.00     19.00
# 75%     2009.00     84.96     13.00     11.60   4958.26   2022.00     26.00
# max     2023.00    317.36     68.00    180.00  29078.35   2023.00     62.00

# %%
prc.describe(include = object)
# Out:
#            아파트       시       구       동      지번     거래월    금액구간  \
# count   175749  175749  175749  175749  175749  175749  175749
# unique    6860       1      25     332    6055      12       2
# top         현대   서울특별시     노원구     상계동    1013      6월   5천 미만
# freq      1471  175749   16590    6635     739   25640  132718
#
#                         주소
# count               175749
# unique                8230
# top     서울특별시 강북구 미아동 1353
# freq                   733

# %%
df1.columns.equals(df2.columns)
# Out:
# True

# %%
df1.head(1)
# Out:
#           아파트      시    구    동   지번    건축년도        거래일   전용면적  층     거래금액
# 123113  파르크한남  서울특별시  용산구  한남동  410 2020.00 2021-12-13 268.95  2  1200000

# %%
df2.head(1)
# Out:
#          아파트      시    구    동      지번    건축년도        거래일   전용면적   층    거래금액
# 1326  타워팰리스3  서울특별시  강남구  도곡동  467-29 2004.00 2020-07-25 235.74  67  542500

# %%
pd.concat(objs = [df1, df2], ignore_index = True)
# Out:
#           아파트      시    구      동       지번    건축년도        거래일   전용면적   층  \
# 0       파르크한남  서울특별시  용산구    한남동      410 2020.00 2021-12-13 268.95   2
# 1       PH129  서울특별시  강남구    청담동      129 2020.00 2022-04-28 273.96  16
# 2   아크로서울포레스트  서울특별시  성동구  성수동1가  685-700 2020.00 2022-09-30 264.55  47
# 3       파르크한남  서울특별시  용산구    한남동      410 2020.00 2022-04-30 268.67   5
# 4       파르크한남  서울특별시  용산구    한남동      410 2020.00 2023-08-17 268.67   4
# 5      타워팰리스3  서울특별시  강남구    도곡동   467-29 2004.00 2020-07-25 235.74  67
# 6      타워팰리스3  서울특별시  강남구    도곡동   467-29 2004.00 2020-10-27 185.62  66
# 7     현대하이페리온  서울특별시  양천구     목동      916 2003.00 2020-07-03 154.05  66
# 8      타워팰리스3  서울특별시  강남구    도곡동   467-29 2004.00 2021-06-24 214.97  66
# 9      타워팰리스3  서울특별시  강남구    도곡동   467-29 2004.00 2023-12-22 185.62  68
# 10    현대하이페리온  서울특별시  양천구     목동      916 2003.00 2023-07-03 167.44  65
#
#        거래금액
# 0   1200000
# 1   1450000
# 2   1300000
# 3   1350000
# 4   1800000
# 5    542500
# ...

# %%
df2 = df2.rename(columns = {'아파트': '아파트명'})

# %%
df1.columns.equals(df2.columns)
# Out:
# False

# %%
pd.concat(objs = [df1, df2], ignore_index = True)
# Out:
#           아파트      시    구      동       지번    건축년도        거래일   전용면적   층  \
# 0       파르크한남  서울특별시  용산구    한남동      410 2020.00 2021-12-13 268.95   2
# 1       PH129  서울특별시  강남구    청담동      129 2020.00 2022-04-28 273.96  16
# 2   아크로서울포레스트  서울특별시  성동구  성수동1가  685-700 2020.00 2022-09-30 264.55  47
# 3       파르크한남  서울특별시  용산구    한남동      410 2020.00 2022-04-30 268.67   5
# 4       파르크한남  서울특별시  용산구    한남동      410 2020.00 2023-08-17 268.67   4
# 5         NaN  서울특별시  강남구    도곡동   467-29 2004.00 2020-07-25 235.74  67
# 6         NaN  서울특별시  강남구    도곡동   467-29 2004.00 2020-10-27 185.62  66
# 7         NaN  서울특별시  양천구     목동      916 2003.00 2020-07-03 154.05  66
# 8         NaN  서울특별시  강남구    도곡동   467-29 2004.00 2021-06-24 214.97  66
# 9         NaN  서울특별시  강남구    도곡동   467-29 2004.00 2023-12-22 185.62  68
# 10        NaN  서울특별시  양천구     목동      916 2003.00 2023-07-03 167.44  65
#
#        거래금액     아파트명
# 0   1200000      NaN
# 1   1450000      NaN
# 2   1300000      NaN
# ...

# %%
pd.concat(objs = [df1, df2], axis = 1)
# Out:
#               아파트      시    구      동       지번    건축년도        거래일   전용면적     층  \
# 123113      파르크한남  서울특별시  용산구    한남동      410 2020.00 2021-12-13 268.95  2.00
# 128446      PH129  서울특별시  강남구    청담동      129 2020.00 2022-04-28 273.96 16.00
# 135998  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700 2020.00 2022-09-30 264.55 47.00
# 138784      파르크한남  서울특별시  용산구    한남동      410 2020.00 2022-04-30 268.67  5.00
# 172266      파르크한남  서울특별시  용산구    한남동      410 2020.00 2023-08-17 268.67  4.00
# 1326          NaN    NaN  NaN    NaN      NaN     NaN        NaT    NaN   NaN
# 1429          NaN    NaN  NaN    NaN      NaN     NaN        NaT    NaN   NaN
# 68048         NaN    NaN  NaN    NaN      NaN     NaN        NaT    NaN   NaN
# 85043         NaN    NaN  NaN    NaN      NaN     NaN        NaT    NaN   NaN
# 141488        NaN    NaN  NaN    NaN      NaN     NaN        NaT    NaN   NaN
# 168579        NaN    NaN  NaN    NaN      NaN     NaN        NaT    NaN   NaN
#
# ...

# %%
os.listdir()
# Out:
# ['APT_Detail_Seoul_2023.csv',
#  'APT_Detail_Seoul_2023.xlsx',
#  'APT_List.pkl',
#  'APT_Price_Seoul(2020~2023).xlsx',
#  'APT_Price_Seoul_2020.csv',
#  'APT_Price_Seoul_2021.csv',
#  'APT_Price_Seoul_2022.csv',
#  'APT_Price_Seoul_2023.csv',
#  'NA_Sample.xlsx',
#  'pivot_table.xlsx']

# %%
dtl = pd.read_excel('APT_Detail_Seoul_2023.xlsx')

# %%
dtl.head()
# Out:
#     아파트ID          아파트명                지번주소    위도     경도  동수   세대수  임대수  용적률  \
# 0  146479         YH빌리지  서울시 강남구 개포동 1237-8 37.48 127.05   1    16    0  297
# 1  119219     개포래미안포레스트    서울시 강남구 개포동 1282 37.48 127.05  31  2296  120  249
# 2  140057  개포비버리하임(도시형)  서울시 강남구 개포동 1193-5 37.47 127.05   2    29    0  199
# 3  107513       개포상지리츠빌   서울시 강남구 개포동 176-1 37.49 127.06   1    18    0  202
# 4    8928          개포자이    서울시 강남구 개포동 12-2 37.50 127.08   4   212    0  250
#
#    건폐율  주차대수        건설사
# 0   59     9  (주)세담종합건설
# 1   21  3961    삼성물산(주)
# 2   57    30   (주)덕인컨스텍
# 3   31    41    상지건영(주)
# 4   18   502    LG건설(주)

# %%
dtl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10576 entries, 0 to 10575
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   아파트ID   10576 non-null  int64
#  1   아파트명    10576 non-null  object
#  2   지번주소    10576 non-null  object
#  3   위도      10576 non-null  float64
#  4   경도      10576 non-null  float64
#  5   동수      10576 non-null  int64
#  6   세대수     10576 non-null  int64
#  7   임대수     10576 non-null  int64
#  8   용적률     10576 non-null  int64
#  9   건폐율     10576 non-null  int64
#  10  주차대수    10576 non-null  int64
#  11  건설사     9985 non-null   object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 991.6+ KB

# %%
prc['아파트'].nunique()
# Out:
# 6860

# %%
len(set(prc['아파트']) & set(dtl['아파트명']))
# Out:
# 2653

# %%
prc['주소'].nunique()
# Out:
# 8230

# %%
len(set(prc['주소']) & set(dtl['지번주소']))
# Out:
# 0

# %%
prc['주소'].head()
# Out:
# 0      서울특별시 강남구 개포동 12
# 1     서울특별시 강남구 개포동 138
# 2    서울특별시 강남구 개포동 12-2
# 3     서울특별시 강남구 개포동 652
# 4      서울특별시 강남구 개포동 12
# Name: 주소, dtype: object

# %%
dtl['지번주소'].head()
# Out:
# 0    서울시 강남구 개포동 1237-8
# 1      서울시 강남구 개포동 1282
# 2    서울시 강남구 개포동 1193-5
# 3     서울시 강남구 개포동 176-1
# 4      서울시 강남구 개포동 12-2
# Name: 지번주소, dtype: object

# %%
prc['주소'] = prc['주소'].str.replace(pat = '특별', repl = '')

# %%
len(set(prc['주소']) & set(dtl['지번주소']))
# Out:
# 6917

# %%
lotto = np.random.choice(a = range(1, 46), size = 6, replace = False)
sorted(lotto)
# Out:
# [1, 4, 7, 18, 28, 40]

# %%
prc.sample(random_state = 1)
# Out:
#       아파트      시    구    동    지번  건축년도        거래일  전용면적  층  거래금액    평당금액  \
# 93237  동부  서울특별시  관악구  신림동  1695  1993 2021-03-06 50.57  2  6.00 3915.36
#
#        거래년도  경과년수 거래월   금액구간                주소
# 93237  2021    28  3월  5천 미만  서울시 관악구 신림동 1695

# %%
for i in range(10):
    np.random.seed(seed = 1)
    lotto = np.random.choice(a = range(1, 46), size = 6, replace = False)
    print(sorted(lotto))
# Out:
# [3, 4, 22, 23, 31, 42]
# [3, 4, 22, 23, 31, 42]
# [3, 4, 22, 23, 31, 42]
# [3, 4, 22, 23, 31, 42]
# [3, 4, 22, 23, 31, 42]
# [3, 4, 22, 23, 31, 42]
# [3, 4, 22, 23, 31, 42]
# [3, 4, 22, 23, 31, 42]
# [3, 4, 22, 23, 31, 42]
# [3, 4, 22, 23, 31, 42]

# %%
np.random.seed(seed = 20240511)
for i in range(10):
    lotto = np.random.choice(a = range(1, 46), size = 6, replace = False)
    print(sorted(lotto))
# Out:
# [2, 3, 5, 25, 26, 30]
# [5, 9, 16, 20, 26, 41]
# [12, 28, 31, 35, 38, 41]
# [1, 11, 20, 27, 35, 40]
# [4, 8, 14, 23, 27, 31]
# [7, 20, 23, 25, 38, 40]
# [3, 17, 26, 35, 39, 41]
# [1, 4, 12, 30, 43, 44]
# [5, 14, 22, 32, 33, 34]
# [8, 11, 15, 16, 39, 43]

# %%
np.random.seed(seed = 1)
nums = np.random.choice(a = range(1, 5), size = 5, replace = True)
nums
# Out:
# array([2, 4, 1, 1, 4])

# %%
nums = pd.Series(data = nums)
nums
# Out:
# 0    2
# 1    4
# 2    1
# 3    1
# 4    4
# dtype: int32

# %%
dups = nums.duplicated(keep = False)
nums.loc[dups]
# Out:
# 1    4
# 2    1
# 3    1
# 4    4
# dtype: int32

# %%
dups = nums.duplicated(keep = 'first')
nums.loc[~dups]
# Out:
# 0    2
# 1    4
# 2    1
# dtype: int32

# %%
dups = dtl['지번주소'].duplicated(keep = False)
dtl.loc[dups, :].sort_values(by = '지번주소')
# Out:
#         아파트ID                  아파트명                 지번주소    위도     경도  동수  \
# 18        419                    대청       서울시 강남구 개포동 12 37.50 127.08   6
# 19        483                 대치2단지       서울시 강남구 개포동 12 37.49 127.08  11
# 8        1303               개포주공6단지      서울시 강남구 개포동 185 37.49 127.07   9
# 9        1307               개포주공7단지      서울시 강남구 개포동 185 37.49 127.07   8
# 476       724                현대6,7차     서울시 강남구 압구정동 456 37.53 127.03  15
# 477     27498         현대65동(대림아크로빌)     서울시 강남구 압구정동 456 37.53 127.03   1
# 1338   133403            미사아름채(도시형)   서울시 강동구 천호동 452-15 37.54 127.13   1
# 1339   133402           미사아름채(주상복합)   서울시 강동구 천호동 452-15 37.54 127.13   1
# 1564   145243   에피소드수유838(민간임대,도시형)      서울시 강북구 수유동 740 37.64 127.02   1
# 1565   145240  에피소드수유838(민간임대,주상복합)      서울시 강북구 수유동 740 37.64 127.02   1
# 2625   123686            노들리안3(도시형)  서울시 관악구 봉천동 1667-13 37.48 126.95   1
# 2626   123685           노들리안3(주상복합)  서울시 관악구 봉천동 1667-13 37.48 126.95   1
# ...

# %%
dups = dtl['지번주소'].duplicated(keep = 'first')
dtl = dtl.loc[~dups, :]

# %%
dtl.shape
# Out:
# (10546, 12)

# %%
set(prc.columns) & set(dtl.columns)
# Out:
# set()

# %%
pd.merge(left = prc, 
         right = dtl, 
         how = 'inner', 
         left_on = '주소', 
         right_on = '지번주소')
# Out:
#                    아파트      시    구    동      지번  건축년도        거래일   전용면적   층  \
# 0           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992 2020-01-04  49.86   6
# 1                 개포자이  서울특별시  강남구  개포동    12-2  2004 2020-01-06 134.30  17
# 2               개포우성3차  서울특별시  강남구  개포동     652  1984 2020-01-09 133.46   3
# 3           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992 2020-01-10  39.53   2
# 4              삼익대청아파트  서울특별시  강남구  개포동      12  1992 2020-01-11  60.00  14
# ...                ...    ...  ...  ...     ...   ...        ...    ...  ..
# 163557  한신아파트(101~102)  서울특별시  중랑구  중화동     450  1998 2023-12-02  59.76   7
# 163558         한영(101)  서울특별시  중랑구  중화동  274-51  2003 2023-12-03  71.83   2
# 163559  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997 2023-12-07  84.69   8
# 163560  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997 2023-12-09  59.76  11
# 163561  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997 2023-12-21  84.87   6
#
# ...
