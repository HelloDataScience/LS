# %%
import numpy as np
import pandas as pd

# %%
li2 = [[1, 2], [3, 4], [5.0, '6']]

# %%
np.array(object = li2)

# %%
df = pd.DataFrame(data = li2)
df

# %%
type(df)

# %%
df.shape

# %%
df.index

# %%
df.columns

# %%
df.dtypes

# %%
type(df.dtypes)

# %%
df.values

# %%
df.info()

# %%
df.index = range(1, 4)

# %%
df

# %%
df.columns = ['A', 'B']

# %%
df

# %%
df = pd.DataFrame(data = li2, index = range(1, 4), columns = ['A', 'B'])
df

# %%
df.iloc[0]

# %%
df.iloc[[0]]

# %%
df.iloc[0:2]

# %%
df.iloc[0:2, :]

# %%
df.iloc[:, 0]

# %%
df.iloc[:, 0:2]

# %%
df.iloc[:, [1, 0]]

# %%
df

# %%
df.loc[1]

# %%
df.loc[[1]]

# %%
df.loc[1:3]

# %%
df.loc[1:2, :]

# %%
df.loc[:, 'A']

# %%
df.loc[:, ['A']]

# %%
df.loc[:, 'A':'B']

# %%
df.loc[:, ['B', 'A']]

# %%
'C:\Users\USER\Documents\project\data'

# %%
'I am a boy'

# %%
'I'm a boy'

# %%
"I'm a boy"

# %%
'I\'m a boy'

# %%
'C:\\Users\\USER\\Documents\\project\\data'

# %%
'C:/Users/USER/Documents/project/data'

# %%
# raw string
r'C:\Users\USER\Documents\project\data'

# %%
import os
import chardet
import joblib

# %%
os.getcwd()

# %%
# 절대 경로 방식
os.chdir('C:\\Users\\USER\\Documents\\project\\data')

# %%
os.getcwd()

# %%
# 상대 경로 방식
os.chdir('..')

# %%
os.getcwd()

# %%
os.chdir('./code')

# %%
os.getcwd()

# %%
os.chdir('../data')

# %%
os.getcwd()

# %%
os.mkdir('temp')

# %%
os.listdir()

# %%
os.rmdir('temp')

# %%
li = [1, 3, 4, 2, 5, 1]

# %%
# 내림차순 정렬
sorted(li, reverse = True)

# %%
files = os.listdir()
files

# %%
for file in files:
    if 'xlsx' in file:
        print(file)

# %%
result = []
for file in files:
    if 'xlsx' in file:
        result.append(file)

# %%
result

# %%
# 리스트 컴프리헨션(내포하다)
result = [file for file in files if 'xlsx' in file]

# %%
result

# %%
file = 'APT_Price_Seoul(2020~2023).xlsx'

# %%
pd.read_excel(io = file)

# %%
pd.read_excel(io = file, 
              sheet_name = '2023년', 
              usecols = range(1, 12), 
              skiprows = 3)

# %%
# %%time
dfs = pd.read_excel(io = file, 
                    sheet_name = None, 
                    usecols = range(1, 12), 
                    skiprows = 3)

# %%
dfs

# %%
dfs.keys()

# %%
for key in dfs.keys():
    df = dfs[key]

# %%
dfs['2023년']

# %%
df1 = pd.DataFrame()
for key in dfs.keys():
    df = dfs[key]
    df1 = pd.concat(objs = [df1, df], ignore_index = True)

# %%
df1.loc[0]

# %%
df1.info()

# %%
df1

# %%
'서울특별시' + ' ' + '강남구' + ' ' + '역삼동' + ' ' + '1'

# %%
'서울특별시' + ' ' + '강남구' + ' ' + '역삼동' + ' ' + np.NaN

# %%
# %time df1.to_excel('test.xlsx', index = False)

# %%
df1.head()

# %%
df1.head(n = 10)

# %%
df1.tail()

# %%
df1.sample(n = 2, random_state = 2)

# %%
df1.sample(n = 2, random_state = 2)

# %%
files = os.listdir()
files

# %%
files = [file for file in files if 'csv' in file and 'Price' in file]
files

# %%
pd.read_csv(files[0])

# %%
with open(file = files[0], mode = 'rb') as file:
    text = file.read()

# %%
text[0:100]

# %%
chardet.detect(text[0:100])

# %%
pd.read_csv(files[0], encoding = 'CP949')

# %%
# %%time
df2 = pd.DataFrame()
for file in files:
    df = pd.read_csv(filepath_or_buffer = file, 
                     encoding = 'CP949', 
                     parse_dates = ['거래일'])
    df2 = pd.concat(objs = [df2, df], ignore_index = True)

# %%
df2.info()

# %%
df2.head()

# %%
# %time df2.to_csv('test.csv', index = False, encoding = 'CP949')

# %%
with open(file = 'test.csv', mode = 'rb') as file:
    text = file.read()
    
chardet.detect(text)

# %%
df3 = pd.read_csv('test.csv', encoding = 'CP949')

# %%
df3.info()

# %%
# %time df2.to_pickle('test.pkl')

# %%
# %time df4 = pd.read_pickle('test.pkl')

# %%
df4.info()

# %%
a = 1
b = 2.0
c = '3'

# %%
pd.to_pickle(obj = [a, b, c], filepath_or_buffer = 'test.pkl')

# %%
pd.read_pickle(filepath_or_buffer='test.pkl')

# %%
a_1, b_1, c_1 = pd.read_pickle(filepath_or_buffer='test.pkl')

# %%
print(a_1)
print(b_1)
print(c_1)

# %%
files = [file for file in os.listdir() if 'test' in file]
files

# %%
for file in files:
    os.remove(file)

# %%
os.listdir()

# %%
df3.to_pickle('APT_List.pkl')

# %%
import os
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\USER\\Documents\\project\\code'

# %%
os.chdir('../data')

# %%
os.listdir()
# Out:
# ['APT_Detail_Seoul_2023.csv',
#  'APT_Detail_Seoul_2023.xlsx',
#  'APT_List.pkl',
#  'APT_Price_Seoul(2020~2023).xlsx',
#  'APT_Price_Seoul_2020.csv',
#  'APT_Price_Seoul_2021.csv',
#  'APT_Price_Seoul_2022.csv',
#  'APT_Price_Seoul_2023.csv',
#  'NA_Sample.xlsx']

# %%
files = [file for file in os.listdir() if 'csv' in file and 'Price' in file]
files

# %%
prc = pd.DataFrame()
for file in files:
    df = pd.read_csv(filepath_or_buffer = file, encoding = 'CP949')
    prc = pd.concat(objs = [prc, df], ignore_index = True)

# %%
prc.to_pickle('APT_List.pkl')

# %%
prc = pd.read_pickle('APT_List.pkl')

# %%
prc.head()
# Out:
#     지역코드         아파트    시도명  시군구  법정동    지번    건축년도         거래일    전용면적   층  \
# 0  11680  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-04   49.86   6
# 1  11680    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019.0  2020-01-04   94.29  12
# 2  11680        개포자이  서울특별시  강남구  개포동  12-2  2004.0  2020-01-06  134.30  17
# 3  11680      개포우성3차  서울특별시  강남구  개포동   652  1984.0  2020-01-09  133.46   3
# 4  11680  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-10   39.53   2
#
#       거래금액
# 0  124,500
# 1  285,000
# 2  203,000
# 3  220,000
# 4  103,000

# %%
prc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175754 entries, 0 to 175753
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   지역코드    175754 non-null  int64
#  1   아파트     175754 non-null  object
#  2   시도명     175754 non-null  object
#  3   시군구     175754 non-null  object
#  4   법정동     175754 non-null  object
#  5   지번      175732 non-null  object
#  6   건축년도    175749 non-null  float64
#  7   거래일     175754 non-null  object
#  8   전용면적    175754 non-null  float64
#  9   층       175754 non-null  int64
#  10  거래금액    175754 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 14.7+ MB

# %%
prc['지역코드']
# Out:
# 0         11680
# 1         11680
# 2         11680
# 3         11680
# 4         11680
#           ...
# 175749    11260
# 175750    11260
# 175751    11260
# 175752    11260
# 175753    11260
# Name: 지역코드, Length: 175754, dtype: int64

# %%
prc[['지역코드']]
# Out:
#          지역코드
# 0       11680
# 1       11680
# 2       11680
# 3       11680
# 4       11680
# ...       ...
# 175749  11260
# 175750  11260
# 175751  11260
# 175752  11260
# 175753  11260
#
# [175754 rows x 1 columns]

# %%
prc[['거래금액', '거래일', '전용면적', '층']]
# Out:
#            거래금액         거래일    전용면적   층
# 0       124,500  2020-01-04   49.86   6
# 1       285,000  2020-01-04   94.29  12
# 2       203,000  2020-01-06  134.30  17
# 3       220,000  2020-01-09  133.46   3
# 4       103,000  2020-01-10   39.53   2
# ...         ...         ...     ...  ..
# 175749   60,000  2023-12-02   59.76   7
# 175750   47,500  2023-12-03   71.83   2
# 175751   73,000  2023-12-07   84.69   8
# 175752   60,000  2023-12-09   59.76  11
# 175753   74,350  2023-12-21   84.87   6
#
# [175754 rows x 4 columns]

# %%
prc[['거래일', '전용면적', '층', '거래금액']]
# Out:
#                거래일    전용면적   층     거래금액
# 0       2020-01-04   49.86   6  124,500
# 1       2020-01-04   94.29  12  285,000
# 2       2020-01-06  134.30  17  203,000
# 3       2020-01-09  133.46   3  220,000
# 4       2020-01-10   39.53   2  103,000
# ...            ...     ...  ..      ...
# 175749  2023-12-02   59.76   7   60,000
# 175750  2023-12-03   71.83   2   47,500
# 175751  2023-12-07   84.69   8   73,000
# 175752  2023-12-09   59.76  11   60,000
# 175753  2023-12-21   84.87   6   74,350
#
# [175754 rows x 4 columns]

# %%
prc['거래일':'거래금액']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 prc['거래일':'거래금액']
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4085, in DataFrame.__getitem__(self, key)
#    4083 # Do we have a slicer (on rows)?
#    4084 if isinstance(key, slice):
# -> 4085     return self._getitem_slice(key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4349, in NDFrame._getitem_slice(self, key)
#    4344 """
#    4345 __getitem__ for the case where the key is a slice object.
#    4346 """
#    4347 # _convert_slice_indexer to determine if this slice is positional
#    4348 #  or label based, and if the latter, convert to positional
# ...

# %%
prc.loc[:, '거래일':'거래금액']
# Out:
#                거래일    전용면적   층     거래금액
# 0       2020-01-04   49.86   6  124,500
# 1       2020-01-04   94.29  12  285,000
# 2       2020-01-06  134.30  17  203,000
# 3       2020-01-09  133.46   3  220,000
# 4       2020-01-10   39.53   2  103,000
# ...            ...     ...  ..      ...
# 175749  2023-12-02   59.76   7   60,000
# 175750  2023-12-03   71.83   2   47,500
# 175751  2023-12-07   84.69   8   73,000
# 175752  2023-12-09   59.76  11   60,000
# 175753  2023-12-21   84.87   6   74,350
#
# [175754 rows x 4 columns]

# %%
prc.dtypes.loc['지역코드']
# Out:
# dtype('int64')

# %%
cond = (prc.dtypes == 'int64')
prc.loc[:, cond]
# Out:
#          지역코드   층
# 0       11680   6
# 1       11680  12
# 2       11680  17
# 3       11680   3
# 4       11680   2
# ...       ...  ..
# 175749  11260   7
# 175750  11260   2
# 175751  11260   8
# 175752  11260  11
# 175753  11260   6
#
# [175754 rows x 2 columns]

# %%
cond = ((prc.dtypes == 'int64') | (prc.dtypes == 'float64'))
prc.loc[:, cond]
# Out:
#          지역코드    건축년도    전용면적   층
# 0       11680  1992.0   49.86   6
# 1       11680  2019.0   94.29  12
# 2       11680  2004.0  134.30  17
# 3       11680  1984.0  133.46   3
# 4       11680  1992.0   39.53   2
# ...       ...     ...     ...  ..
# 175749  11260  1998.0   59.76   7
# 175750  11260  2003.0   71.83   2
# 175751  11260  1997.0   84.69   8
# 175752  11260  1997.0   59.76  11
# 175753  11260  1997.0   84.87   6
#
# [175754 rows x 4 columns]

# %%
prc.select_dtypes(include = [int, float])
# Out:
#          지역코드    건축년도    전용면적   층
# 0       11680  1992.0   49.86   6
# 1       11680  2019.0   94.29  12
# 2       11680  2004.0  134.30  17
# 3       11680  1984.0  133.46   3
# 4       11680  1992.0   39.53   2
# ...       ...     ...     ...  ..
# 175749  11260  1998.0   59.76   7
# 175750  11260  2003.0   71.83   2
# 175751  11260  1997.0   84.69   8
# 175752  11260  1997.0   59.76  11
# 175753  11260  1997.0   84.87   6
#
# [175754 rows x 4 columns]

# %%
prc.columns
# Out:
# Index(['지역코드', '아파트', '시도명', '시군구', '법정동', '지번', '건축년도', '거래일', '전용면적', '층',
#        '거래금액'],
#       dtype='object')

# %%
cond = prc.columns.str.contains(pat = '거래')
prc.loc[:, cond]
# Out:
#                거래일     거래금액
# 0       2020-01-04  124,500
# 1       2020-01-04  285,000
# 2       2020-01-06  203,000
# 3       2020-01-09  220,000
# 4       2020-01-10  103,000
# ...            ...      ...
# 175749  2023-12-02   60,000
# 175750  2023-12-03   47,500
# 175751  2023-12-07   73,000
# 175752  2023-12-09   60,000
# 175753  2023-12-21   74,350
#
# [175754 rows x 2 columns]

# %%
prc.drop(labels = '지역코드', axis = 1)
# Out:
#                    아파트    시도명  시군구  법정동      지번    건축년도         거래일    전용면적  \
# 0           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-04   49.86
# 1             디에이치아너힐즈  서울특별시  강남구  개포동     138  2019.0  2020-01-04   94.29
# 2                 개포자이  서울특별시  강남구  개포동    12-2  2004.0  2020-01-06  134.30
# 3               개포우성3차  서울특별시  강남구  개포동     652  1984.0  2020-01-09  133.46
# 4           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-10   39.53
# ...                ...    ...  ...  ...     ...     ...         ...     ...
# 175749  한신아파트(101~102)  서울특별시  중랑구  중화동     450  1998.0  2023-12-02   59.76
# 175750         한영(101)  서울특별시  중랑구  중화동  274-51  2003.0  2023-12-03   71.83
# 175751  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-07   84.69
# 175752  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-09   59.76
# 175753  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-21   84.87
#
#          층     거래금액
# 0        6  124,500
# ...

# %%
prc.drop(index = 0)
# Out:
#          지역코드             아파트    시도명  시군구  법정동      지번    건축년도         거래일  \
# 1       11680        디에이치아너힐즈  서울특별시  강남구  개포동     138  2019.0  2020-01-04
# 2       11680            개포자이  서울특별시  강남구  개포동    12-2  2004.0  2020-01-06
# 3       11680          개포우성3차  서울특별시  강남구  개포동     652  1984.0  2020-01-09
# 4       11680      성원대치2단지아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-10
# 5       11680         삼익대청아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-11
# ...       ...             ...    ...  ...  ...     ...     ...         ...
# 175749  11260  한신아파트(101~102)  서울특별시  중랑구  중화동     450  1998.0  2023-12-02
# 175750  11260         한영(101)  서울특별시  중랑구  중화동  274-51  2003.0  2023-12-03
# 175751  11260  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-07
# 175752  11260  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-09
# 175753  11260  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-21
#
#           전용면적   층     거래금액
# 1        94.29  12  285,000
# ...

# %%
prc.drop(columns = '지역코드')
# Out:
#                    아파트    시도명  시군구  법정동      지번    건축년도         거래일    전용면적  \
# 0           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-04   49.86
# 1             디에이치아너힐즈  서울특별시  강남구  개포동     138  2019.0  2020-01-04   94.29
# 2                 개포자이  서울특별시  강남구  개포동    12-2  2004.0  2020-01-06  134.30
# 3               개포우성3차  서울특별시  강남구  개포동     652  1984.0  2020-01-09  133.46
# 4           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-10   39.53
# ...                ...    ...  ...  ...     ...     ...         ...     ...
# 175749  한신아파트(101~102)  서울특별시  중랑구  중화동     450  1998.0  2023-12-02   59.76
# 175750         한영(101)  서울특별시  중랑구  중화동  274-51  2003.0  2023-12-03   71.83
# 175751  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-07   84.69
# 175752  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-09   59.76
# 175753  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-21   84.87
#
#          층     거래금액
# 0        6  124,500
# ...

# %%
prc.head()
# Out:
#     지역코드         아파트    시도명  시군구  법정동    지번    건축년도         거래일    전용면적   층  \
# 0  11680  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-04   49.86   6
# 1  11680    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019.0  2020-01-04   94.29  12
# 2  11680        개포자이  서울특별시  강남구  개포동  12-2  2004.0  2020-01-06  134.30  17
# 3  11680      개포우성3차  서울특별시  강남구  개포동   652  1984.0  2020-01-09  133.46   3
# 4  11680  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-10   39.53   2
#
#       거래금액
# 0  124,500
# 1  285,000
# 2  203,000
# 3  220,000
# 4  103,000

# %%
# prc.drop(columns = '지역코드', inplace = True)
prc = prc.drop(columns = '지역코드')

# %%
prc.head()
# Out:
#           아파트    시도명  시군구  법정동    지번    건축년도         거래일    전용면적   층     거래금액
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-04   49.86   6  124,500
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019.0  2020-01-04   94.29  12  285,000
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004.0  2020-01-06  134.30  17  203,000
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984.0  2020-01-09  133.46   3  220,000
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-10   39.53   2  103,000

# %%
prc.rename(columns = {'시도명': '시', '시군구': '구', '법정동': '동'})
# Out:
#                    아파트      시    구    동      지번    건축년도         거래일    전용면적  \
# 0           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-04   49.86
# 1             디에이치아너힐즈  서울특별시  강남구  개포동     138  2019.0  2020-01-04   94.29
# 2                 개포자이  서울특별시  강남구  개포동    12-2  2004.0  2020-01-06  134.30
# 3               개포우성3차  서울특별시  강남구  개포동     652  1984.0  2020-01-09  133.46
# 4           성원대치2단지아파트  서울특별시  강남구  개포동      12  1992.0  2020-01-10   39.53
# ...                ...    ...  ...  ...     ...     ...         ...     ...
# 175749  한신아파트(101~102)  서울특별시  중랑구  중화동     450  1998.0  2023-12-02   59.76
# 175750         한영(101)  서울특별시  중랑구  중화동  274-51  2003.0  2023-12-03   71.83
# 175751  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-07   84.69
# 175752  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-09   59.76
# 175753  한신아파트(103~109)  서울특별시  중랑구  중화동     450  1997.0  2023-12-21   84.87
#
#          층     거래금액
# 0        6  124,500
# ...

# %%
prc.columns
# Out:
# Index(['아파트', '시도명', '시군구', '법정동', '지번', '건축년도', '거래일', '전용면적', '층', '거래금액'], dtype='object')

# %%
prc.columns = ['아파트', '시', '구', '동', '지번', '건축년도', 
               '거래일', '전용면적', '층', '거래금액']

# %%
prc.head()
# Out:
#           아파트      시    구    동    지번    건축년도         거래일    전용면적   층     거래금액
# 0  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-04   49.86   6  124,500
# 1    디에이치아너힐즈  서울특별시  강남구  개포동   138  2019.0  2020-01-04   94.29  12  285,000
# 2        개포자이  서울특별시  강남구  개포동  12-2  2004.0  2020-01-06  134.30  17  203,000
# 3      개포우성3차  서울특별시  강남구  개포동   652  1984.0  2020-01-09  133.46   3  220,000
# 4  성원대치2단지아파트  서울특별시  강남구  개포동    12  1992.0  2020-01-10   39.53   2  103,000

# %%
prc['거래금액'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 prc['거래금액'].mean()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
# ...

# %%
prc['거래금액'] = prc['거래금액'].str.replace(pat = ',', repl = '')
prc['거래금액'] = prc['거래금액'].astype(float)

# %%
prc['거래금액'] = prc['거래금액'].str.replace(pat = ',', repl = '') \
                                 .astype(float)

# %%
prc['거래금액'].mean()
# Out:
# 94431.40133368231

# %%
prc.dtypes
# Out:
# 아파트      object
# 시        object
# 구        object
# 동        object
# 지번       object
# 건축년도    float64
# 거래일      object
# 전용면적    float64
# 층         int64
# 거래금액    float64
# dtype: object

# %%
prc = prc.astype({'거래일': 'datetime64[ns]', '층': float})

# %%
prc.dtypes
# Out:
# 아파트             object
# 시               object
# 구               object
# 동               object
# 지번              object
# 건축년도           float64
# 거래일     datetime64[ns]
# 전용면적           float64
# 층              float64
# 거래금액           float64
# dtype: object

# %%
# prc['층'] = prc['층'].astype(int)
# prc['거래금액'] = prc['거래금액'].astype(int)

cols = ['층', '거래금액']
prc[cols] = prc[cols].astype('int64')
prc.dtypes
# Out:
# 아파트             object
# 시               object
# 구               object
# 동               object
# 지번              object
# 건축년도           float64
# 거래일     datetime64[ns]
# 전용면적           float64
# 층                int64
# 거래금액             int64
# dtype: object

# %%
date = '2000년 1월 1일'

# %%
pd.Series(data = [date]).astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 pd.Series(data = [date]).astype('datetime64[ns]')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
birth = pd.to_datetime(arg = date, format = '%Y년 %m월 %d일')
birth
# Out:
# Timestamp('2000-01-01 00:00:00')

# %%
birth.timestamp()
# Out:
# 946684800.0

# %%
today = pd.Timestamp.today()
today
# Out:
# Timestamp('2024-05-08 17:10:35.291617')

# %%
today.timestamp()
# Out:
# 1715188235.291617

# %%
dtGap = today - birth
dtGap
# Out:
# Timedelta('8894 days 17:10:35.291617')

# %%
dtGap.days * 3 * 8000
# Out:
# 213456000

# %%
prc['거래일'].dt.year
# Out:
# 0         2020
# 1         2020
# 2         2020
# 3         2020
# 4         2020
#           ...
# 175749    2023
# 175750    2023
# 175751    2023
# 175752    2023
# 175753    2023
# Name: 거래일, Length: 175754, dtype: int32

# %%
prc['거래일'].dt.month
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 175749    12
# 175750    12
# 175751    12
# 175752    12
# 175753    12
# Name: 거래일, Length: 175754, dtype: int32

# %%
prc['거래일'].dt.day
# Out:
# 0          4
# 1          4
# 2          6
# 3          9
# 4         10
#           ..
# 175749     2
# 175750     3
# 175751     7
# 175752     9
# 175753    21
# Name: 거래일, Length: 175754, dtype: int32

# %%
prc['거래일'].dt.day_name()
# Out:
# 0         Saturday
# 1         Saturday
# 2           Monday
# 3         Thursday
# 4           Friday
#             ...
# 175749    Saturday
# 175750      Sunday
# 175751    Thursday
# 175752    Saturday
# 175753    Thursday
# Name: 거래일, Length: 175754, dtype: object

# %%
prc['거래일'].dt.day_name(locale = 'ko_KR')
# Out:
# 0         토요일
# 1         토요일
# 2         월요일
# 3         목요일
# 4         금요일
#          ...
# 175749    토요일
# 175750    일요일
# 175751    목요일
# 175752    토요일
# 175753    목요일
# Name: 거래일, Length: 175754, dtype: object

# %%
prc['거래일'].dt.strftime(date_format = '%a %b %d, %Y')
# Out:
# 0         Sat Jan 04, 2020
# 1         Sat Jan 04, 2020
# 2         Mon Jan 06, 2020
# 3         Thu Jan 09, 2020
# 4         Fri Jan 10, 2020
#                 ...
# 175749    Sat Dec 02, 2023
# 175750    Sun Dec 03, 2023
# 175751    Thu Dec 07, 2023
# 175752    Sat Dec 09, 2023
# 175753    Thu Dec 21, 2023
# Name: 거래일, Length: 175754, dtype: object

# %%
prc['거래일'].iloc[0]
# Out:
# Timestamp('2020-01-04 00:00:00')

# %%
prc['거래일'].iloc[0].replace(day = 1, hour = 12, minute = 30, second = 59)
# Out:
# Timestamp('2020-01-01 12:30:59')

# %%
blood = pd.Series(data = ['O', 'A', 'B']).astype('category')
blood
# Out:
# 0    O
# 1    A
# 2    B
# dtype: category
# Categories (3, object): ['A', 'B', 'O']

# %%
blood.cat.codes
# Out:
# 0    2
# 1    0
# 2    1
# dtype: int8

# %%
prc['구'].astype('category')
# Out:
# 0         강남구
# 1         강남구
# 2         강남구
# 3         강남구
# 4         강남구
#          ...
# 175749    중랑구
# 175750    중랑구
# 175751    중랑구
# 175752    중랑구
# 175753    중랑구
# Name: 구, Length: 175754, dtype: category
# Categories (25, object): ['강남구', '강동구', '강북구', '강서구', ..., '은평구', '종로구', '중구', '중랑구']

# %%
cond = prc['거래금액'] >= 1200000
df1 = prc.loc[cond, :]
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층  \
# 123113      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2
# 128446      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 135998  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
# 138784      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 172266      파르크한남  서울특별시  용산구    한남동      410  2020.0 2023-08-17  268.670   4
#
#            거래금액
# 123113  1200000
# 128446  1450000
# 135998  1300000
# 138784  1350000
# 172266  1800000

# %%
cond = (prc['거래금액'] < 1200000) & (prc['층'] >= 65)
df2 = prc.loc[cond, :]
df2
# Out:
#             아파트      시    구    동      지번    건축년도        거래일     전용면적   층  \
# 1326     타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2020-07-25  235.740  67
# 1429     타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2020-10-27  185.622  66
# 68048   현대하이페리온  서울특별시  양천구   목동     916  2003.0 2020-07-03  154.050  66
# 85043    타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2021-06-24  214.967  66
# 141488   타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2023-12-22  185.622  68
# 168579  현대하이페리온  서울특별시  양천구   목동     916  2003.0 2023-07-03  167.440  65
#
#           거래금액
# 1326    542500
# 1429    380000
# 68048   240000
# 85043   458000
# 141488  550000
# 168579  320000

# %%
prc['층'].gt(65).sum()
# Out:
# 5

# %%
prc['층'].ge(65).sum()
# Out:
# 6

# %%
prc['층'].lt(65).sum()
# Out:
# 175748

# %%
prc['층'].le(65).sum()
# Out:
# 175749

# %%
prc['층'].eq(65).sum()
# Out:
# 1

# %%
prc['층'].ne(65).sum()
# Out:
# 175753

# %%
prc['거래금액'].lt(1200000) & prc['층'].ge(65)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 175749    False
# 175750    False
# 175751    False
# 175752    False
# 175753    False
# Length: 175754, dtype: bool
